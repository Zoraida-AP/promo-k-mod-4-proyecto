# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np


# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # christmas_billboard_data ✨

# %%
# cargamos el dataframe correspondiente 
df = pd.read_csv("archivos/christmas_billboard_data.csv")

display(df.head(25))
# Out:
#                                                  url      weekid  \
# 0  http://www.billboard.com/charts/hot-100/1958-1...  12/13/1958
# 1  http://www.billboard.com/charts/hot-100/1958-1...  12/20/1958
# 2  http://www.billboard.com/charts/hot-100/1958-1...  12/20/1958
# 3  http://www.billboard.com/charts/hot-100/1958-1...  12/20/1958
# 4  http://www.billboard.com/charts/hot-100/1958-1...  12/27/1958
#
#    week_position              song     performer                       songid  \
# 0             83   RUN RUDOLPH RUN   Chuck Berry   Run Rudolph RunChuck Berry
# 1             57  JINGLE BELL ROCK   Bobby Helms  Jingle Bell RockBobby Helms
# 2             73   RUN RUDOLPH RUN   Chuck Berry   Run Rudolph RunChuck Berry
# 3             86   WHITE CHRISTMAS   Bing Crosby   White ChristmasBing Crosby
# 4             44   GREEN CHRI$TMA$  Stan Freberg  Green Chri$tma$Stan Freberg
#
#    instance  previous_week_position  peak_position  weeks_on_chart  year  \
# 0         1                     NaN             69               3  1958
# 1         1                     NaN             29              19  1958
# 2         1                    83.0             69               3  1958
# 3         1                     NaN             12              13  1958
# 4         1                     NaN             44               2  1958
#
#    month  day
# 0     12   13
# 1     12   20
# 2     12   20
# 3     12   20
# 4     12   27

# %%
def exploracion(df):
    df_info = pd.DataFrame()
    df_info["% nulos"] = round(df.isna().sum()/df.shape[0]*100, 2).astype(str)+"%"
    df_info["% no_nulos"] = round(df.notna().sum()/df.shape[0]*100, 2).astype(str)+"%"
    df_info["tipo_dato"] = df.dtypes
    df_info["num_valores_unicos"] = df.nunique()
    print(f"""El DataFrame tiene {df.shape[0]} filas y {df.shape[1]} columnas.
Tiene {df.duplicated().sum()} datos duplicados, lo que supone un porcentaje de {round(df.duplicated().sum()/df.shape[0], 2)}% de los datos.
Hay {len(list(df_info[(df_info["% nulos"] != "0.0%")].index))} columnas con datos nulos, y son:
{list(df_info[(df_info["% nulos"] != "0.0%")].index)}
y sin nulos hay {len(list(df_info[(df_info["% nulos"] == "0.0%")].index))} columnas y son:
{list(df_info[(df_info["% nulos"] == "0.0%")].index)}
A continuación tienes un detalle sobre los datos nulos y los tipos y número de datos:""")
    display(df_info.head())
    print("Principales estadísticos de las columnas categóricas:")
    display(df.describe(include="O").T)
    print("Principales estadísticos de las columnas numéricas:")
    display(df.describe(exclude="O").T)
    return df_info

exploracion(df)
# Out:
# El DataFrame tiene 387 filas y 13 columnas.
# Tiene 0 datos duplicados, lo que supone un porcentaje de 0.0% de los datos.
# Hay 1 columnas con datos nulos, y son:
# ['previous_week_position']
# y sin nulos hay 12 columnas y son:
# ['url', 'weekid', 'week_position', 'song', 'performer', 'songid', 'instance', 'peak_position', 'weeks_on_chart', 'year', 'month', 'day']
# A continuación tienes un detalle sobre los datos nulos y los tipos y número de datos:
#               % nulos % no_nulos tipo_dato  num_valores_unicos
# url              0.0%     100.0%    object                 206
# weekid           0.0%     100.0%    object                 206
# week_position    0.0%     100.0%     int64                  89
# song             0.0%     100.0%    object                  70
# performer        0.0%     100.0%    object                  69
# Principales estadísticos de las columnas categóricas:
#           count unique                                                top freq
# url         387    206  http://www.billboard.com/charts/hot-100/1960-1...   10
# weekid      387    206                                         12/17/1960   10
# song        387     70                                   JINGLE BELL ROCK   28
# performer   387     69                                       Mariah Carey   20
# songid      387     78                        Jingle Bell RockBobby Helms   20
# Principales estadísticos de las columnas numéricas:
#                         count         mean        std     min     25%     50%  \
# week_position           387.0    57.204134  25.398527     7.0    38.5    58.0
# instance                387.0     1.586563   1.250751     1.0     1.0     1.0
# previous_week_position  279.0    55.519713  25.147310     7.0    35.0    57.0
# peak_position           387.0    37.534884  24.760630     7.0    14.0    34.0
# weeks_on_chart          387.0     9.645995   6.142627     1.0     5.0     8.0
# year                    387.0  1982.064599  21.118797  1958.0  1962.0  1975.0
# month                   387.0     7.754522   5.325586     1.0     1.0    12.0
# day                     387.0    16.671835   8.904113     1.0     9.0    17.0
#
#                            75%     max
# week_position             78.0   100.0
# instance                   1.0     6.0
# previous_week_position    75.0   100.0
# peak_position             53.5   100.0
# weeks_on_chart            15.0    20.0
# year                    2005.0  2017.0
# month                     12.0    12.0
# day                       24.0    31.0
#                        % nulos % no_nulos tipo_dato  num_valores_unicos
# url                       0.0%     100.0%    object                 206
# weekid                    0.0%     100.0%    object                 206
# week_position             0.0%     100.0%     int64                  89
# song                      0.0%     100.0%    object                  70
# performer                 0.0%     100.0%    object                  69
# songid                    0.0%     100.0%    object                  78
# instance                  0.0%     100.0%     int64                   6
# previous_week_position  27.91%     72.09%   float64                  83
# peak_position             0.0%     100.0%     int64                  61
# weeks_on_chart            0.0%     100.0%     int64                  18
# year                      0.0%     100.0%     int64                  46
# month                     0.0%     100.0%     int64                   3
# day                       0.0%     100.0%     int64                  31

# %% [markdown]
# # Valores unicos de las variables categoricas ✨

# %%
# creamos una lista con los nombres de las columnas categoricas 
columnas = df.select_dtypes(include='object').columns.tolist()
print(columnas)
# empezamos a iterar por cada una de las columnas para sacar sus valores únicos y sus frecuencias
for columna in columnas:
    print(f" \n----------- ESTAMOS ANALIZANDO LA COLUMNA: '{columna.upper()}' -----------\n")
    print(f"Sus valores únicos son: {df[columna].unique()}\n")
    print(f"Las frecuencias de los valores únicos de las categorías son: {df[columna].value_counts()} ")
# Out:
# ['url', 'weekid', 'song', 'performer', 'songid']
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'URL' -----------
#
# Sus valores únicos son: ['http://www.billboard.com/charts/hot-100/1958-12-13'
#  'http://www.billboard.com/charts/hot-100/1958-12-20'
#  'http://www.billboard.com/charts/hot-100/1958-12-27'
#  'http://www.billboard.com/charts/hot-100/1959-01-03'
#  'http://www.billboard.com/charts/hot-100/1959-01-10'
#  'http://www.billboard.com/charts/hot-100/1959-12-05'
#  'http://www.billboard.com/charts/hot-100/1959-12-12'
#  'http://www.billboard.com/charts/hot-100/1959-12-19'
#  'http://www.billboard.com/charts/hot-100/1959-12-26'
#  'http://www.billboard.com/charts/hot-100/1960-01-02'
#  'http://www.billboard.com/charts/hot-100/1960-01-09'
#  'http://www.billboard.com/charts/hot-100/1960-01-16'
#  'http://www.billboard.com/charts/hot-100/1960-12-10'
#  'http://www.billboard.com/charts/hot-100/1960-12-17'
#  'http://www.billboard.com/charts/hot-100/1960-12-24'
#  'http://www.billboard.com/charts/hot-100/1960-12-31'
#  'CHRISTMAS AULD LANG SYNE' 'BLUE CHRISTMAS' 'CHILD OF GOD'
#  'LITTLE ALTAR BOY' "BABY'S FIRST CHRISTMAS"
#  'PLEASE COME HOME FOR CHRISTMAS' "MONSTERS' HOLIDAY"
#  'SANTA CLAUS IS WATCHING YOU' 'THE MARVELOUS TOY' 'PRETTY PAPER' 'AMEN'
#  "I'LL BE HOME" 'MY FAVORITE THINGS' 'WINTER WORLD OF LOVE'
#  'IF WE MAKE IT THROUGH DECEMBER' "IT DOESN'T HAVE TO BE THAT WAY"
#  'WHEN A CHILD IS BORN' 'CHRISTMAS DREAM' 'CHRISTMAS FOR COWBOYS'
#  'I BELIEVE IN FATHER CHRISTMAS' 'SAME OLD LANG SYNE'
#  'WHAT CAN YOU GET A WOOKIEE FOR CHRISTMAS (WHEN HE ALREADY OWNS A COMB?)'
#  'MERRY CHRISTMAS IN THE NFL' 'THE GREATEST GIFT OF ALL'
#  "DO THEY KNOW IT'S CHRISTMAS?" "THIS ONE'S FOR THE CHILDREN"
#  'LET IT SNOW' 'THE SANTA CLAUS BOOGIE' 'MACARENA CHRISTMAS'
#  "SANTA'S A FAT BITCH" 'GRANDMA GOT RUN OVER BY A REINDEER'
#  'AULD LANG SYNE' 'DECK THE HALLS' 'THIS GIFT'
#  'ALL I WANT FOR CHRISTMAS IS YOU' 'THE CHRISTMAS SHOES'
#  'WHERE ARE YOU CHRISTMAS?' 'BETTER DAYS' 'BELIEVE'
#  'GREATEST TIME OF YEAR' 'A GREAT BIG SLED' 'RIVER'
#  'HAPPY XMAS (WAR IS OVER)' 'THIS CHRISTMAS' 'MISTLETOE' 'LAST CHRISTMAS'
#  'CHRISTMAS LIGHTS' 'WELCOME CHRISTMAS' "BABY, IT'S COLD OUTSIDE"
#  'OH SANTA!' 'SHAKE UP CHRISTMAS'
#  "IT'S BEGINNING TO LOOK A LOT LIKE CHRISTMAS"
#  "I'LL BE HOME FOR CHRISTMAS" 'UNDERNEATH THE TREE' 'SANTA TELL ME'
#  'HAVE YOURSELF A MERRY LITTLE CHRISTMAS' 'A HOLLY JOLLY CHRISTMAS'
#  'FELIZ NAVIDAD' "IT'S THE MOST WONDERFUL TIME OF THE YEAR"]
#
# Las frecuencias de los valores únicos de las categorías son: song
# JINGLE BELL ROCK                               28
# ALL I WANT FOR CHRISTMAS IS YOU                20
# ROCKIN' AROUND THE CHRISTMAS TREE              19
# WHITE CHRISTMAS                                16
# THE CHIPMUNK SONG (CHRISTMAS DON'T BE LATE)    16
#                                                ..
# CHILD OF GOD                                    1
# HAVE YOURSELF A MERRY LITTLE CHRISTMAS          1
# A HOLLY JOLLY CHRISTMAS                         1
# FELIZ NAVIDAD                                   1
# IT'S THE MOST WONDERFUL TIME OF THE YEAR        1
# Name: count, Length: 70, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'PERFORMER' -----------
#
# Sus valores únicos son: ['Chuck Berry' 'Bobby Helms' 'Bing Crosby' 'Stan Freberg'
#  'Dancer, Prancer And Nervous' 'David Seville And The Chipmunks'
#  'Brook Benton' 'Nat King Cole' 'Brenda Lee' 'Santo & Johnny'
#  'Bobby Darin' 'The Browns Featuring Jim Edward Brown'
#  'The Drifters Featuring Clyde McPhatter And Bill Pinkney' 'Vic Dana'
#  'Bobby Rydell/Chubby Checker' 'Connie Francis' 'Charles Brown'
#  'Bobby "Boris" Pickett And The Crypt-Kickers' 'Ray Stevens'
#  'The Chad Mitchell Trio' 'Roy Orbison' 'The Impressions' 'The Platters'
#  'Herb Alpert & The Tijuana Brass' 'Engelbert Humperdinck' 'Merle Haggard'
#  'Jim Croce' 'Michael Holm' 'Perry Como' 'John Denver' 'Greg Lake'
#  'Eagles' 'Dan Fogelberg'
#  'The Star Wars Intergalactic Droid Choir & Chorale'
#  'Willis "The Guard" & Vigorish' 'Kenny Rogers' 'Band-Aid'
#  'New Kids On The Block' 'Boyz II Men' 'The Tractors' 'Los Del Rio'
#  'Insane Clown Posse' 'Elmo & Patsy' 'Kenny G' 'SHeDAISY' '98 Degrees'
#  'Mariah Carey' 'NewSong' 'Faith Hill' 'Goo Goo Dolls' 'Brooks & Dunn'
#  'Aly & AJ' 'The Killers Featuring Toni Halliday' 'Sarah McLachlan'
#  'The Fray' 'Chris Brown' 'Colbie Caillat' 'Glee Cast' 'Coldplay' 'Train'
#  'Justin Bieber' 'Michael Buble' 'Kelly Clarkson' 'Ariana Grande'
#  'Sam Smith' 'Wham!' 'Burl Ives' 'Jose Feliciano' 'Andy Williams']
#
# Las frecuencias de los valores únicos de las categorías son: performer
# Mariah Carey                       20
# Bobby Helms                        20
# Brenda Lee                         19
# Bing Crosby                        16
# David Seville And The Chipmunks    16
#                                    ..
# Faith Hill                          1
# Sam Smith                           1
# Burl Ives                           1
# Jose Feliciano                      1
# Andy Williams                       1
# Name: count, Length: 69, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'SONGID' -----------
#
# Sus valores únicos son: ['Run Rudolph RunChuck Berry' 'Jingle Bell RockBobby Helms'
#  'White ChristmasBing Crosby' 'Green Chri$tma$Stan Freberg'
#  'The Happy ReindeerDancer, Prancer And Nervous'
#  "The Chipmunk Song (Christmas Don't Be Late)David Seville And The Chipmunks"
#  'This Time Of The YearBrook Benton'
#  'The Christmas Song (Merry Christmas To You)Nat King Cole'
#  "Rockin' Around The Christmas TreeBrenda Lee" 'Silent NightBing Crosby'
#  "Twistin' BellsSanto & Johnny" 'Christmas Auld Lang SyneBobby Darin'
#  'Blue ChristmasThe Browns Featuring Jim Edward Brown'
#  'White ChristmasThe Drifters Featuring Clyde McPhatter And Bill Pinkney'
#  'Child Of GodBobby Darin' 'Little Altar BoyVic Dana'
#  'Jingle Bell RockBobby Rydell/Chubby Checker'
#  "Baby's First ChristmasConnie Francis"
#  'Please Come Home For ChristmasCharles Brown'
#  'Monsters\' HolidayBobby "Boris" Pickett And The Crypt-Kickers'
#  'Santa Claus Is Watching YouRay Stevens'
#  'The Marvelous ToyThe Chad Mitchell Trio' 'Pretty PaperRoy Orbison'
#  'AmenThe Impressions' "I'll Be HomeThe Platters"
#  'My Favorite ThingsHerb Alpert & The Tijuana Brass'
#  'Winter World Of LoveEngelbert Humperdinck'
#  'If We Make It Through DecemberMerle Haggard'
#  "It Doesn't Have To Be That WayJim Croce"
#  'When A Child Is BornMichael Holm' 'Christmas DreamPerry Como'
#  'Christmas For CowboysJohn Denver'
#  'I Believe In Father ChristmasGreg Lake'
#  'Please Come Home For ChristmasEagles' 'Same Old Lang SyneDan Fogelberg'
#  'What Can You Get A Wookiee For Christmas (When He Already Owns A Comb?)The Star Wars Intergalactic Droid Choir & Chorale'
#  'Merry Christmas In The NFLWillis "The Guard" & Vigorish'
#  'The Greatest Gift Of AllKenny Rogers'
#  "Do They Know It's Christmas?Band-Aid"
#  "This One's For The ChildrenNew Kids On The Block"
#  'Let It SnowBoyz II Men' 'The Santa Claus BoogieThe Tractors'
#  'Macarena ChristmasLos Del Rio' "Santa's A Fat BitchInsane Clown Posse"
#  'Grandma Got Run Over By A ReindeerElmo & Patsy' 'Auld Lang SyneKenny G'
#  'Deck The HallsSHeDAISY' 'This Gift98 Degrees'
#  'All I Want For Christmas Is YouMariah Carey'
#  'The Christmas ShoesNewSong' 'Where Are You Christmas?Faith Hill'
#  'Better DaysGoo Goo Dolls' 'BelieveBrooks & Dunn'
#  'Greatest Time Of YearAly & AJ'
#  'A Great Big SledThe Killers Featuring Toni Halliday'
#  'RiverSarah McLachlan' 'Happy Xmas (War Is Over)The Fray'
#  'This ChristmasChris Brown' 'MistletoeColbie Caillat'
#  'Last ChristmasGlee Cast' 'Christmas LightsColdplay'
#  'Welcome ChristmasGlee Cast' "Baby, It's Cold OutsideGlee Cast"
#  'Oh Santa!Mariah Carey' 'Shake Up ChristmasTrain'
#  'MistletoeJustin Bieber'
#  "It's Beginning To Look A Lot Like ChristmasMichael Buble"
#  "I'll Be Home For ChristmasKelly Clarkson"
#  "Do They Know It's Christmas?Glee Cast"
#  'All I Want For Christmas Is YouMichael Buble'
#  'Last ChristmasAriana Grande' 'Underneath The TreeKelly Clarkson'
#  'Santa Tell MeAriana Grande'
#  'Have Yourself A Merry Little ChristmasSam Smith' 'Last ChristmasWham!'
#  'A Holly Jolly ChristmasBurl Ives' 'Feliz NavidadJose Feliciano'
#  "It's The Most Wonderful Time Of The YearAndy Williams"]
#
# Las frecuencias de los valores únicos de las categorías son: songid
# Jingle Bell RockBobby Helms                                                   20
# All I Want For Christmas Is YouMariah Carey                                   19
# Rockin' Around The Christmas TreeBrenda Lee                                   19
# The Chipmunk Song (Christmas Don't Be Late)David Seville And The Chipmunks    16
# White ChristmasBing Crosby                                                    14
#                                                                               ..
# Shake Up ChristmasTrain                                                        1
# It's Beginning To Look A Lot Like ChristmasMichael Buble                       1
# A Holly Jolly ChristmasBurl Ives                                               1
# Feliz NavidadJose Feliciano                                                    1
# It's The Most Wonderful Time Of The YearAndy Williams                          1
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# # DUPLICADOS

# %%
def get_duplicate_rows(df):
    """
    Encuentra y devuelve las filas completas duplicadas de un DataFrame.

    Args:
        df (pd.DataFrame): El DataFrame de entrada.

    Returns:
        pd.DataFrame: Un nuevo DataFrame con las filas duplicadas completas.
    """
    # Identificar duplicados basados en todas las columnas
    duplicate_rows = df[df.duplicated(keep=False)]
    return duplicate_rows

get_duplicate_rows(df)
# Out:
# Empty DataFrame
# Columns: [url, weekid, week_position, song, performer, songid, instance, previous_week_position, peak_position, weeks_on_chart, year, month, day]
# Index: []
